# %%
from bs4 import BeautifulSoup

# %%
with open("htmls/page-10.html") as file:
    content = file.read()

# %%
soup = BeautifulSoup(content, 'html.parser')

# %%
articles = soup.select("article.product_pod")

# %%
items = []

for article in articles:
    title = article.find("h3").find("a")["title"]
    price = article.select_one("p.price_color").text.split("£")[1]
    stock = article.select_one("p.instock").text.strip()
    rating_element = article.select_one("p.star-rating")
    rating = rating_element['class'][1]
    items.append([title, price, stock, rating])

# %%
items
# Out:
# [['Modern Romance', '28.26', 'In stock', 'Five'],
#  ['Miss PeregrineÃ¢Â€Â™s Home for Peculiar Children (Miss PeregrineÃ¢Â€Â™s Peculiar Children #1)',
#   '10.76',
#   'In stock',
#   'One'],
#  ['Louisa: The Extraordinary Life of Mrs. Adams', '16.85', 'In stock', 'Two'],
#  ['Little Red', '13.47', 'In stock', 'Three'],
#  ['Library of Souls (Miss PeregrineÃ¢Â€Â™s Peculiar Children #3)',
#   '48.56',
#   'In stock',
#   'Five'],
#  ['Large Print Heart of the Pride', '19.15', 'In stock', 'Two'],
#  ['I Had a Nice Time And Other Lies...: How to find love & sh*t like that',
#   '57.36',
#   'In stock',
#   'Four'],
#  ['Hollow City (Miss PeregrineÃ¢Â€Â™s Peculiar Children #2)',
#   '42.98',
#   'In stock',
#   'One'],
#  ['Grumbles', '22.16', 'In stock', 'Two'],
#  ['Full Moon over NoahÃ¢Â€Â™s Ark: An Odyssey to Mount Ararat and Beyond',
#   '49.43',
#   'In stock',
#   'Four'],
#  ['Frostbite (Vampire Academy #2)', '29.99', 'In stock', 'Five'],
#  ['Follow You Home', '21.36', 'In stock', 'One'],
#  ['First Steps for New Christians (Print Edition)',
#   '29.00',
#   'In stock',
#   'One'],
#  ['Finders Keepers (Bill Hodges Trilogy #2)', '53.53', 'In stock', 'Five'],
#  ['Fables, Vol. 1: Legends in Exile (Fables #1)', '41.62', 'In stock', 'Four'],
#  ['Eureka Trivia 6.0', '54.59', 'In stock', 'Four'],
#  ['Drive: The Surprising Truth About What Motivates Us',
#   '34.95',
#   'In stock',
#   'Four'],
#  ['Done Rubbed Out (Reightman & Bailey #1)', '37.72', 'In stock', 'Five'],
#  ['Doing It Over (Most Likely To #1)', '35.61', 'In stock', 'Three'],
#  ['Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free Snacks, Packed Lunches, and Simple Meals',
#   '42.16',
#   'In stock',
#   'Three']]

# %%
import pandas as pd

# %%
df = pd.DataFrame(items, columns=["Title", "Price", "Availability", "Rating (Star)"])

# %%
df
# Out:
#                                                 Title  Price Availability  \
# 0                                      Modern Romance  28.26     In stock
# 1   Miss PeregrineÃ¢Â€Â™s Home for Peculiar Childr...  10.76     In stock
# 2        Louisa: The Extraordinary Life of Mrs. Adams  16.85     In stock
# 3                                          Little Red  13.47     In stock
# 4   Library of Souls (Miss PeregrineÃ¢Â€Â™s Peculi...  48.56     In stock
# 5                      Large Print Heart of the Pride  19.15     In stock
# 6   I Had a Nice Time And Other Lies...: How to fi...  57.36     In stock
# 7   Hollow City (Miss PeregrineÃ¢Â€Â™s Peculiar Ch...  42.98     In stock
# 8                                            Grumbles  22.16     In stock
# 9   Full Moon over NoahÃ¢Â€Â™s Ark: An Odyssey to ...  49.43     In stock
# 10                     Frostbite (Vampire Academy #2)  29.99     In stock
# 11                                    Follow You Home  21.36     In stock
# 12     First Steps for New Christians (Print Edition)  29.00     In stock
# 13           Finders Keepers (Bill Hodges Trilogy #2)  53.53     In stock
# 14       Fables, Vol. 1: Legends in Exile (Fables #1)  41.62     In stock
# 15                                  Eureka Trivia 6.0  54.59     In stock
# 16  Drive: The Surprising Truth About What Motivat...  34.95     In stock
# 17            Done Rubbed Out (Reightman & Bailey #1)  37.72     In stock
# 18                  Doing It Over (Most Likely To #1)  35.61     In stock
# 19  Deliciously Ella Every Day: Quick and Easy Rec...  42.16     In stock
#
#    Rating (Star)
# 0           Five
# 1            One
# 2            Two
# 3          Three
# 4           Five
# 5            Two
# 6           Four
# 7            One
# 8            Two
# 9           Four
# 10          Five
# 11           One
# 12           One
# 13          Five
# 14          Four
# 15          Four
# 16          Four
# 17          Five
# 18         Three
# 19         Three

# %%
df.to_csv("My Practice (page-10).csv", index=False)
