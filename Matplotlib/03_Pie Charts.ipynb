# %% [markdown]
# # 🍰 **Pie Charts in Matplotlib**
#
# ## 🥧 **Matplotlib Pie Charts**
# Pie charts are a great way to visualize **part-to-whole relationships**. They're visually appealing but work best when there are **fewer categories**—too many slices can lead to **clutter**. 🧑‍💻
#
# ---
#
# ## 🎨 **Setting a Style**
# Matplotlib allows you to customize your plot’s look. You can easily set a style to make it more visually engaging!
#
# ```python
# import matplotlib.pyplot as plt
#
# plt.style.use("ggplot")  # Choose any style you like
# ````
#
# ---
#
# ## 📊 **Basic Pie Chart Example**
#
# Visualizing the career runs of Indian cricketers in a simple pie chart.
#
# ### **Data**:
#
# ```python
# labels = ["Sachin", "Sehwag", "Kohli", "Yuvraj"]
# runs = [18000, 8000, 12000, 9500]
#
# plt.title("Career Runs of Indian Batsmen")
# plt.pie(runs, labels=labels)
# plt.show()
# ```
#
# ---
#
# ## 🌈 **Custom Colors**
#
# You can **customize the colors** of the pie slices by using either **color names** or **hex codes**.
#
# ```python
# colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99']
# plt.pie(runs, labels=labels, colors=colors)
# plt.show()
# ```
#
# ---
#
# ## 🖋️ **Add Edges and Style Slices with `wedgeprops`**
#
# Want to customize the **slice edges**? Use `wedgeprops` for more control!
#
# ```python
# plt.pie(
#     runs,
#     labels=labels,
#     colors=colors,
#     wedgeprops={'edgecolor': 'black', 'linewidth': 2, 'linestyle': '--'}
# )
# plt.show()
# ```
#
# > **Tip**: Google **“matplotlib wedgeprops”** for additional customization options. 📚
#
# [**Visit the official documentation**](https://matplotlib.org/stable/api/_as_gen/matplotlib.patches.Wedge.html)
#
# ---
#
# ## 💥 **Highlight a Slice Using `explode`**
#
# Use **`explode`** to bring attention to one or more slices by pulling them out.
#
# ```python
# explode = [0.1, 0, 0, 0]  # Only highlight Sachin's slice
#
# plt.pie(runs, labels=labels, explode=explode, colors=colors)
# plt.title("Exploded Pie Example")
# plt.show()
# ```
#
# ---
#
# ## 🌟 **Add Shadows for a 3D Feel**
#
# Give your pie chart some **depth** with shadows!
#
# ```python
# plt.pie(
#     runs,
#     labels=labels,
#     explode=explode,
#     colors=colors,
#     shadow=True  # adds a 3D-like shadow
# )
# plt.show()
# ```
#
# ---
#
# ## 🔄 **Start Angle**
#
# You can control the **rotation** of the pie chart by setting a **starting angle**.
#
# ```python
# plt.pie(
#     runs,
#     labels=labels,
#     explode=explode,
#     colors=colors,
#     shadow=True,
#     startangle=140
# )
# plt.show()
# ```
#
# ---
#
# ## 📉 **Show Percentages with `autopct`**
#
# Want to display the **percentages** of each slice? Use the **`autopct`** parameter.
#
# ```python
# plt.pie(
#     runs,
#     labels=labels,
#     autopct='%1.1f%%',
#     startangle=140
# )
# plt.title("Career Run Share")
# plt.show()
# ```
#
# ---
#
# ## 🚫 **Crowded Pie Chart – Why to Avoid**
#
# Be mindful when creating pie charts with **too many categories**. Here's an example that demonstrates why it's not ideal:
#
# ### Example of a **Crowded Pie Chart**:
#
# ```python
# languages = ['Python', 'Java', 'C++', 'JavaScript', 'C#', 'Ruby', 'Go', 'Rust', 'Swift', 'PHP']
# usage = [30, 20, 10, 10, 7, 5, 4, 3, 2, 1]
#
# plt.pie(usage, labels=languages, autopct='%1.1f%%', startangle=90)
# plt.title("Programming Language Usage (Crowded Example)")
# plt.show()
# ```
#
# ### Why avoid it?
#
# * **Hard to compare slice sizes visually**
# * **Cluttered and confusing** 🌀
# * **No clear insight** 🤷‍♂️
#
# **Better alternatives**: **bar charts** or **horizontal bar charts** 📊.
#
# ---
#
# ## 📋 **Summary of Useful Pie Chart Parameters**
#
# | **Parameter**    | **Description**                                      |
# | ---------------- | ---------------------------------------------------- |
# | **`labels`**     | Labels for each slice                                |
# | **`colors`**     | Customize slice colors (names or hex codes)          |
# | **`explode`**    | Pull out slices for emphasis                         |
# | **`shadow`**     | Adds **depth-like shadow** effect                    |
# | **`startangle`** | Rotates pie to start from a **different angle**      |
# | **`autopct`**    | Displays **percentage** text on slices               |
# | **`wedgeprops`** | Customizes slice **edge**, **fill**, **width**, etc. |
#
# ---
#
# ## 📝 **Assignment:**
#
# ### **Create a Pie Chart:**
#
# Create a **pie chart** that displays the market share of mobile operating systems. Here's a possible breakdown:
#
# * **Android**: 70%
# * **iOS**: 25%
# * **Others**: 5%
#
# **Next, recreate this pie chart as a horizontal bar chart** and compare which one is easier to interpret. 📱
#
# ---

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')

# %%
labels = ["Sachin", "Sehwag", "Kohli", "Yuvraj"]
runs = [18000, 8000, 12000, 9500]

plt.title("Career Runs of Batsmen")
plt.pie(runs, labels = labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x1bf8dfd8a10>,
#   <matplotlib.patches.Wedge at 0x1bf8dca7e90>,
#   <matplotlib.patches.Wedge at 0x1bf8dfd9310>,
#   <matplotlib.patches.Wedge at 0x1bf8dfd9760>],
#  [Text(0.4083169456239889, 1.0214094536062885, 'Sachin'),
#   Text(-1.0706592766215497, 0.2523662286919946, 'Sehwag'),
#   Text(-0.5074751936730054, -0.9759451459003964, 'Kohli'),
#   Text(0.8899187482945414, -0.6465637025335375, 'Yuvraj')])

# %%
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99']
plt.pie(runs, labels=labels, colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x1bf8e8502f0>,
#   <matplotlib.patches.Wedge at 0x1bf8e7e56d0>,
#   <matplotlib.patches.Wedge at 0x1bf8e8516a0>,
#   <matplotlib.patches.Wedge at 0x1bf8e851a60>],
#  [Text(0.4083169456239889, 1.0214094536062885, 'Sachin'),
#   Text(-1.0706592766215497, 0.2523662286919946, 'Sehwag'),
#   Text(-0.5074751936730054, -0.9759451459003964, 'Kohli'),
#   Text(0.8899187482945414, -0.6465637025335375, 'Yuvraj')])

# %%
plt.pie(
    runs,
    labels=labels,
    colors=colors,
    wedgeprops={'edgecolor': 'black', 'linewidth': 2, 'linestyle': '--'}
)
# Out:
# ([<matplotlib.patches.Wedge at 0x1bf8e883da0>,
#   <matplotlib.patches.Wedge at 0x1bf8dfdb530>,
#   <matplotlib.patches.Wedge at 0x1bf8e8bc3b0>,
#   <matplotlib.patches.Wedge at 0x1bf8e8bc830>],
#  [Text(0.4083169456239889, 1.0214094536062885, 'Sachin'),
#   Text(-1.0706592766215497, 0.2523662286919946, 'Sehwag'),
#   Text(-0.5074751936730054, -0.9759451459003964, 'Kohli'),
#   Text(0.8899187482945414, -0.6465637025335375, 'Yuvraj')])

# %%
explode = [0.1, 0, 0, 0]      # Only highlight Sachin's slice

plt.pie(
    runs,
    labels = labels,
    explode = explode,
    colors = colors,
    shadow=True,
    startangle=100,
    autopct="%1.1f%%"
)
plt.title("Exploded Pie Example")
# Out:
# Text(0.5, 1.0, 'Exploded Pie Example')

# %%
languages = ['Python', 'Java', 'C++', 'JavaScript', 'C#', 'Ruby', 'Go', 'Rust', 'Swift', 'PHP']
usage = [30, 20, 10, 10, 7, 5, 4, 3, 2, 1]

plt.pie(usage, labels=languages, autopct='%1.1f%%', startangle=90)
plt.title("Programming Language Usage (Crowded Example)")
# Out:
# Text(0.5, 1.0, 'Programming Language Usage (Crowded Example)')
